# %%
# Run this cell first to import some modules
# we'll need to run the examples below.
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML

from pydrake.multibody.rigid_body_tree import (
    RigidBodyTree,
    FloatingBaseType
)
from pydrake.multibody.rigid_body_plant import (
    RigidBodyPlant
)
from pydrake.systems.analysis import Simulator
from pydrake.systems.framework import (
    Context,
    DiagramBuilder,
    LeafSystem,
    PortDataType,
    BasicVector
)
from pydrake.systems.primitives import (
    SignalLogger
)
from planar_rigid_body_visualizer import PlanarRigidBodyVisualizer
from manipulator_dynamics import manipulator_dynamics
from IPython.display import HTML

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 20.0)
import bldc
reload(bldc)
from bldc import *

Xlen = 1
Ylen = 1
Zlen = 1
M = 1
barmagnet = BarMagnet(Xlen, Ylen, Zlen, M)

x = np.linspace(-2, 2, 30)
y = np.linspace(-2, 2, 30)
X,Y = np.meshgrid(x, y)

H = barmagnet.ComputeFieldAtPoints(X, Y, 0)

plt.imshow(H[1, :, :], extent=(-2, 2, -2, 2))
plt.quiver(X, Y, H[0, :, :], H[1, :, :])
